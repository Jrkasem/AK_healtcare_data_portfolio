# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
dataset_path = r"C:\Users\Dell\Downloads\Lown_Hospital_Index_Equity_GradeRank.xlsx"
df = pd.read_excel(dataset_path)

# Perform exploratory data analysis
# Display basic information about the dataset
print(df.info())

# Summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Visualize distribution of Lown Composite Overall Rank
sns.histplot(df['Tier 1_Lown Composite Overall Rank'], kde=True)
plt.xlabel('Lown Composite Overall Rank')
plt.ylabel('Count')
plt.title('Distribution of Lown Composite Overall Rank')
plt.show()

# Correlation heatmap
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Explore equity-related metrics
# Boxplot of Pay Equity Rank by Hospital Type
sns.boxplot(data=df, x='Type_For Profit', y='Tier 3_Pay Equity Rank')
plt.xlabel('Hospital Type (For Profit)')
plt.ylabel('Pay Equity Rank')
plt.title('Pay Equity Rank by Hospital Type')
plt.show()

# Bar plot of Community Benefit Grade by Ownership Type
sns.barplot(data=df, x='Type_NonProfit', y='Tier 3_Community Benefit Grade')
plt.xlabel('Ownership Type (Non-Profit)')
plt.ylabel('Community Benefit Grade')
plt.title('Community Benefit Grade by Ownership Type')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4071 entries, 0 to 4070
# Data columns (total 30 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   RECORD_ID                                                   4071 non-null   object
#  1   HOSPITAL_SYSTEM                                             4071 non-null   object
#  2   Name                                                        4071 non-null   object
#  3   State                                                       4071 non-null   object
#  4   City                                                        3764 non-null   object
#  5   Address                                                     3764 non-null   object
#  6   Zip                                                         3764 non-null   float64
#  7   Size                                                        4071 non-null   object
#  8   Type_For Profit                                             4071 non-null   int64
#  9   Type_NonProfit                                              4071 non-null   int64
#  10  Type_Church Affiliated                                      3764 non-null   float64
#  11  Type_Urban                                                  3764 non-null   float64
#  12  Type_Rural                                                  3764 non-null   float64
#  13  Tier 1_Lown Composite Overall Rank                          3913 non-null   float64
#  14  Tier 1_Lown Composite Overall Grade                         3913 non-null   object
#  15  Tier 2_Equity Overall Rank                                  4071 non-null   int64
#  16  Tier 2_Equity Overall Grade                                 4071 non-null   object
#  17  Tier 3_Pay Equity Rank                                      4071 non-null   int64
#  18  Tier 3_Pay Equity Grade                                     4071 non-null   object
#  19  Tier 3_Community Benefit Rank                               3987 non-null   float64
#  20  Tier 3_Community Benefit Grade                              3987 non-null   object
#  21  Tier 3_Inclusivity Rank                                     3604 non-null   float64
#  22  Tier 3_Inclusivity Grade                                    3604 non-null   object
#  23  Tier 4_Pay Equity_Exec Comp to Worker Wages Rank            4071 non-null   int64
#  24  Tier 4_Comm Benefit_Charity Care Spending Rank              3963 non-null   float64
#  25  Tier 4_Comm Benefit_Other Benefit Spending Rank             2725 non-null   float64
#  26  Tier 4_Comm Benefit_Medicaid Rev Share of Patient Rev Rank  3969 non-null   float64
#  27  Tier 4_Inclusivity_Income Rank                              3603 non-null   float64
#  28  Tier 4_Inclusivity_Racial Rank                              3107 non-null   float64
#  29  Tier 4_Inclusivity_Education Rank                           3603 non-null   float64
# dtypes: float64(13), int64(5), object(12)
# memory usage: 954.3+ KB
# None
#                 Zip  Type_For Profit  Type_NonProfit  Type_Church Affiliated  \
# count   3764.000000      4071.000000     4071.000000             3764.000000
# mean   52769.402497         0.137804        0.862196                0.120882
# std    26511.126134         0.344736        0.344736                0.326033
# min     1040.000000         0.000000        0.000000                0.000000
# 25%    32293.500000         0.000000        1.000000                0.000000
# 50%    53113.000000         0.000000        1.000000                0.000000
# 75%    74850.750000         0.000000        1.000000                0.000000
# max    99901.000000         1.000000        1.000000                1.000000
#
#         Type_Urban   Type_Rural  Tier 1_Lown Composite Overall Rank  \
# count  3764.000000  3764.000000                         3913.000000
# mean      0.607333     0.392667                         1674.086123
# std       0.488409     0.488409                         1093.722746
# min       0.000000     0.000000                            1.000000
# 25%       0.000000     0.000000                          672.000000
# 50%       1.000000     0.000000                         1650.000000
# 75%       1.000000     1.000000                         2628.000000
# max       1.000000     1.000000                         3606.000000
#
#        Tier 2_Equity Overall Rank  Tier 3_Pay Equity Rank  \
# count                 4071.000000             4071.000000
# mean                  1752.151314             1752.151314
# std                   1140.542032             1140.542032
# min                      1.000000                1.000000
# 25%                    711.500000              711.500000
# 50%                   1729.000000             1729.000000
# 75%                   2746.500000             2746.500000
# max                   3764.000000             3764.000000
#
#        Tier 3_Community Benefit Rank  Tier 3_Inclusivity Rank  \
# count                    3987.000000              3604.000000
# mean                     1710.639077              1524.974195
# std                      1115.660989              1002.825866
# min                         1.000000                 1.000000
# 25%                       690.500000               598.750000
# 50%                      1687.000000              1499.500000
# 75%                      2683.500000              2400.250000
# max                      3680.000000              3301.000000
#
#        Tier 4_Pay Equity_Exec Comp to Worker Wages Rank  \
# count                                       4071.000000
# mean                                        1752.151314
# std                                         1140.542032
# min                                            1.000000
# 25%                                          711.500000
# 50%                                         1729.000000
# 75%                                         2746.500000
# max                                         3764.000000
#
#        Tier 4_Comm Benefit_Charity Care Spending Rank  \
# count                                     3963.000000
# mean                                      1698.782236
# std                                       1108.547903
# min                                          1.000000
# 25%                                        684.500000
# 50%                                       1675.000000
# 75%                                       2665.500000
# max                                       3656.000000
#
#        Tier 4_Comm Benefit_Other Benefit Spending Rank  \
# count                                      2725.000000
# mean                                       1113.361101
# std                                         746.114407
# min                                           1.000000
# 25%                                         404.000000
# 50%                                        1085.000000
# 75%                                        1766.000000
# max                                        2447.000000
#
#        Tier 4_Comm Benefit_Medicaid Rev Share of Patient Rev Rank  \
# count                                        3969.000000
# mean                                         1701.746284
# std                                          1110.326354
# min                                             1.000000
# 25%                                           686.000000
# 50%                                          1678.000000
# 75%                                          2670.000000
# max                                          3662.000000
#
#        Tier 4_Inclusivity_Income Rank  Tier 4_Inclusivity_Racial Rank  \
# count                     3603.000000                     3107.000000
# mean                      1524.481266                     1286.199549
# std                       1002.528289                      856.138323
# min                          1.000000                        1.000000
# 25%                        598.500000                      481.500000
# 50%                       1499.000000                     1258.000000
# 75%                       2399.500000                     2034.500000
# max                       3300.000000                     2811.000000
#
#        Tier 4_Inclusivity_Education Rank
# count                        3603.000000
# mean                         1524.481266
# std                          1002.528289
# min                             1.000000
# 25%                           598.500000
# 50%                          1499.000000
# 75%                          2399.500000
# max                          3300.000000
# RECORD_ID                                                        0
# HOSPITAL_SYSTEM                                                  0
# Name                                                             0
# State                                                            0
# City                                                           307
# Address                                                        307
# Zip                                                            307
# Size                                                             0
# Type_For Profit                                                  0
# Type_NonProfit                                                   0
# Type_Church Affiliated                                         307
# Type_Urban                                                     307
# Type_Rural                                                     307
# Tier 1_Lown Composite Overall Rank                             158
# Tier 1_Lown Composite Overall Grade                            158
# Tier 2_Equity Overall Rank                                       0
# Tier 2_Equity Overall Grade                                      0
# Tier 3_Pay Equity Rank                                           0
# Tier 3_Pay Equity Grade                                          0
# Tier 3_Community Benefit Rank                                   84
# Tier 3_Community Benefit Grade                                  84
# Tier 3_Inclusivity Rank                                        467
# Tier 3_Inclusivity Grade                                       467
# Tier 4_Pay Equity_Exec Comp to Worker Wages Rank                 0
# Tier 4_Comm Benefit_Charity Care Spending Rank                 108
# Tier 4_Comm Benefit_Other Benefit Spending Rank               1346
# Tier 4_Comm Benefit_Medicaid Rev Share of Patient Rev Rank     102
# Tier 4_Inclusivity_Income Rank                                 468
# Tier 4_Inclusivity_Racial Rank                                 964
# Tier 4_Inclusivity_Education Rank                              468
# dtype: int64

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# c:\Users\Dell\Downloads\ahmed proftoloii\AK\AK_healtcare_data_portfolio
